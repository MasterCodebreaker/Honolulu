# %%
import pandas as pd
import plotly.graph_objects as go
import numpy as np
import tadasets
import plotly.express as px


input = "./cool_big_data" # FIXED!!!
how_many = 3
how_long_gold_line = 20



"""
SOMETHINGS WRONG WITHT THE LAST COORDINATED :)


"""

# %%
fig = go.Figure()

df = pd.read_csv("sim_data/all_loss_" + str(1) + ".csv" )

fig.add_trace(go.Scatter(y = np.array(np.array([df.iloc[-1,-1]]*how_long_gold_line)),
    mode='lines',
    name='TARGET',
    marker=dict(
        color='gold',
    )),

    )


for i in range(2,how_many+2,1):

    df = pd.read_csv("sim_data/all_loss_" + str(i) + ".csv" )
    fig.add_trace(go.Scatter(y = df.iloc[:,0],
    mode='lines',
    name='iteration_' + str(i),
    line=dict(
        shape  ='linear'
    )
    )
    )
    

fig.show()

# %%
#HERE
file_number = 3
iteration = -1


#poles
df = pd.read_csv("sim_data/all_points_"+ str(file_number) + ".csv")
L = df.iloc[:,iteration]
#L = [35,47,62,31,79,10]


# colours
df1 = pd.read_csv("sim_data/all_ab_"+ str(file_number) + ".csv")
c_1 = df1.iloc[:,iteration]
co_1 = np.mod(c_1,1.0)

df2 = pd.read_csv("sim_data/all_cd_"+ str(file_number) + ".csv")
c_2 = df2.iloc[:,iteration]
co_2 = np.mod(c_2,1.0)

df3 = pd.read_csv("sim_data/all_ef_"+ str(file_number) + ".csv")
c_3 = df3.iloc[:,iteration]
co_3 = np.mod(c_3,1.0)

#points
ok = input + ".csv"
data = np.genfromtxt(ok, delimiter=',')
x = data[:,0]
y = data[:,1]
z = data[:,2]

# %%
fig = go.Figure(data=[go.Scatter3d(
    x=x,
    y=y,
    z=z,
    mode='markers',
    text = [str(i) for i in co_1],
    #text = [str(x) for x in d],
    marker=dict(
        size=4,
        color = np.mod(co_1,1.0),             # set color to an array/list of desired values
        colorscale='HSV',
        # choose a colorscale
        opacity=0.6
    )
)])

fig.add_trace(
    go.Scatter3d(
    x = data[np.array(L[:2], dtype=int)][:,0],
    y = data[np.array(L[:2], dtype=int)][:,1],
    z = data[np.array(L[:2], dtype=int)][:,2], mode = "markers",
      
      marker=dict(
        #c = "black",
        size=10,
        color = 0,             # set color to an array/list of desired values
        colorscale='magma',
        # choose a colorscale
        opacity=0.6
    )))


fig.add_trace(
    go.Scatter3d(
    x = data[np.array(L[2:4], dtype=int)][:,0],
    y = data[np.array(L[2:4], dtype=int)][:,1],
    z = data[np.array(L[2:4], dtype=int)][:,2], mode = "markers",
      
      marker=dict(
        #color = "black",
        size=10,
        color = 1,             # set color to an array/list of desired values
        colorscale='magma',
        # choose a colorscale
        opacity=0.6
    )))

fig.add_trace(
    go.Scatter3d(
    x = data[np.array(L[4:], dtype=int)][:,0],
    y = data[np.array(L[4:], dtype=int)][:,1],
    z = data[np.array(L[4:], dtype=int)][:,2], mode = "markers",
      
      marker=dict(
        #color = "black",
        size=10,
        color = 0.5, 
        colorscale='magma',            # set color to an array/list of desired values
        #colorscale='black',
        # choose a colorscale
        opacity=0.6
    )))


fig.show()

# %%
fig = go.Figure(data=[go.Scatter3d(
    x=x,
    y=y,
    z=z,
    mode='markers',
    text = [str(i) for i in co_2],
    #text = [str(x) for x in d],
    marker=dict(
        size=4,
        color = np.mod(co_2,1.0),             # set color to an array/list of desired values
        colorscale='HSV',
        # choose a colorscale
        opacity=0.6
    )
)])

fig.add_trace(
    go.Scatter3d(
    x = data[np.array(L[:2], dtype=int)][:,0],
    y = data[np.array(L[:2], dtype=int)][:,1],
    z = data[np.array(L[:2], dtype=int)][:,2], mode = "markers",
      
      marker=dict(
        #c = "black",
        size=10,
        color = 0,             # set color to an array/list of desired values
        colorscale='magma',
        # choose a colorscale
        opacity=0.6
    )))


fig.add_trace(
    go.Scatter3d(
    x = data[np.array(L[2:4], dtype=int)][:,0],
    y = data[np.array(L[2:4], dtype=int)][:,1],
    z = data[np.array(L[2:4], dtype=int)][:,2], mode = "markers",
      
      marker=dict(
        #color = "black",
        size=10,
        color = 1,             # set color to an array/list of desired values
        colorscale='magma',
        # choose a colorscale
        opacity=0.6
    )))

fig.add_trace(
    go.Scatter3d(
    x = data[np.array(L[4:], dtype=int)][:,0],
    y = data[np.array(L[4:], dtype=int)][:,1],
    z = data[np.array(L[4:], dtype=int)][:,2], mode = "markers",
      
      marker=dict(
        #color = "black",
        size=10,
        color = 0.5, 
        colorscale='magma',            # set color to an array/list of desired values
        #colorscale='black',
        # choose a colorscale
        opacity=0.6
    )))


fig.show()

# %%
fig = go.Figure(data=[go.Scatter3d(
    x=x,
    y=y,
    z=z,
    mode='markers',
    text = [str(i) for i in co_3],
    #text = [str(x) for x in d],
    marker=dict(
        size=4,
        color = np.mod(co_3,1.0),             # set color to an array/list of desired values
        colorscale='HSV',
        # choose a colorscale
        opacity=0.6
    )
)])

fig.add_trace(
    go.Scatter3d(
    x = data[np.array(L[:2], dtype=int)][:,0],
    y = data[np.array(L[:2], dtype=int)][:,1],
    z = data[np.array(L[:2], dtype=int)][:,2], mode = "markers",
      
      marker=dict(
        #c = "black",
        size=10,
        color = 0,             # set color to an array/list of desired values
        colorscale='magma',
        # choose a colorscale
        opacity=0.6
    )))


fig.add_trace(
    go.Scatter3d(
    x = data[np.array(L[2:4], dtype=int)][:,0],
    y = data[np.array(L[2:4], dtype=int)][:,1],
    z = data[np.array(L[2:4], dtype=int)][:,2], mode = "markers",
      
      marker=dict(
        #color = "black",
        size=10,
        color = 1,             # set color to an array/list of desired values
        colorscale='magma',
        # choose a colorscale
        opacity=0.6
    )))

fig.add_trace(
    go.Scatter3d(
    x = data[np.array(L[4:], dtype=int)][:,0],
    y = data[np.array(L[4:], dtype=int)][:,1],
    z = data[np.array(L[4:], dtype=int)][:,2], mode = "markers",
      
      marker=dict(
        #color = "black",
        size=10,
        color = 0.5, 
        colorscale='magma',            # set color to an array/list of desired values
        #colorscale='black',
        # choose a colorscale
        opacity=0.6
    )))


fig.show()
